# %%
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

plt.figure(figsize=(10, 6))
sns.catplot(x='salary_in_usd', kind='box', data=data, height=6, aspect=2)
plt.title('USD Salary distribution')
plt.xlabel('Salary (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.catplot(x='experience_level', y='salary_in_usd', kind='box', data=data, height=6, aspect=2, palette='Set2')
plt.title('USD Salary Distribution by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.catplot(x='remote_ratio', y='salary_in_usd', kind='box', data=data, height=6, aspect=2, palette='Set2')
plt.title('USD Salary Distribution by Remote Ratio')
plt.xlabel('Remote Ratio')
plt.ylabel('Salary (USD)')
plt.grid(True)
plt.show()
